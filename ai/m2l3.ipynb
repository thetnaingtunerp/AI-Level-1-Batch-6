# %%
# Task 1: Question
print("preds > 0.5 converts probability predictions to binary predictions. Values > 0.5 become True (1), others False (0). .astype(int) converts booleans to 0/1, and .flatten() ensures 1D array.")


# Task 2 & 4: Print performance metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

def print_metrics(model_name, y_true, y_pred):
    print(f"\n=== {model_name} ===")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
    print(f"Precision: {precision_score(y_true, y_pred):.4f}")
    print(f"Recall: {recall_score(y_true, y_pred):.4f}")
    print(f"F1-Score: {f1_score(y_true, y_pred):.4f}")
    print(f"Confusion Matrix:\n{confusion_matrix(y_true, y_pred)}")

# Example usage (with actual predictions):
# print_metrics("Keras Model", keras_true_labels, keras_preds)
# print_metrics("PyTorch Model", pytorch_true_labels, pytorch_preds)


# Task 3: Question
print("\nF1 score is the harmonic mean of precision and recall. It's significant for imbalanced datasets as it balances both false positives and false negatives, providing a single metric that captures both types of errors.")


# Task 5: Question on false negatives
print("\nFalse negatives are the top-right cell in the confusion matrix (actual=1, predicted=0).")
print("To get false negatives count: cm[1][0] where cm is the confusion matrix.")
